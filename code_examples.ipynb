# %% [markdown]
# # if Statements

# %%
x = int(raw_input("Please enter an integer: "))
if x<0:
    print "Zahl ist negativ"
elif x==0:
    print "Zahl ist 0"
else:
    print "Zahl ist positiv"
# Out:
# Please enter an integer: -8
# Zahl ist negativ

# %% [markdown]
# # for Statement

# %%
words = ['cat', 'window', 'defenestrate']
for w in words:
    print w,len(w)
# Out:
# cat 3
# window 6
# defenestrate 12

# %% [markdown]
# #while Statement

# %%
while True:
    x=raw_input("Zahl eingeben")
    try: 
        x=int(x)
        print "ok"
    except:
        break
# Out:
# Zahl eingeben4
# ok
# Zahl eingeben8
# ok
# Zahl eingebensd

# %% [markdown]
# # function

# %%
def f(x,y):
    z=x+y
    print z

f(1,2)
# Out:
# 3

# %%
from numpy  import *
a = array([[1,2,3,4],
           [5,6,7,8]])
a[1,2]
# Out:
# 7
